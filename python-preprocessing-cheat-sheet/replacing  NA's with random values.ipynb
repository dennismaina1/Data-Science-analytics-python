# %%
import numpy as np
import pandas as pd
import warnings

# %%
penguins=pd.read_csv('data/penguins_lter.csv')
penguins
# Out:
#     studyName  Sample Number                              Species  Region  \
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2     PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4     PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 339   PAL0910            120    Gentoo penguin (Pygoscelis papua)  Anvers
# 340   PAL0910            121    Gentoo penguin (Pygoscelis papua)  Anvers
# 341   PAL0910            122    Gentoo penguin (Pygoscelis papua)  Anvers
# 342   PAL0910            123    Gentoo penguin (Pygoscelis papua)  Anvers
# 343   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# ...

# %%
#isolate the null data
penguins1=penguins[penguins["Sex"].isna()]

penguins1
# Out:
#     studyName  Sample Number                              Species  Region  \
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 8     PAL0708              9  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 9     PAL0708             10  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 10    PAL0708             11  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 11    PAL0708             12  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 47    PAL0708             48  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 246   PAL0708             27    Gentoo penguin (Pygoscelis papua)  Anvers
# 286   PAL0809             67    Gentoo penguin (Pygoscelis papua)  Anvers
# 324   PAL0910            105    Gentoo penguin (Pygoscelis papua)  Anvers
# 339   PAL0910            120    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# ...

# %%
#create the data to replace null values randomly and put them in a list

sex=[]

numbers =(np.random.randint(0,2,10))
numbers=pd.Series(numbers)

numbers
Sex=[]
for i in numbers:
    if i==0:
        sex='MALE'
    else:
        sex="FEMALE"
    print(sex)
    Sex.append(sex)
i +=1
# Out:
# MALE
# MALE
# MALE
# FEMALE
# MALE
# MALE
# MALE
# FEMALE
# FEMALE
# FEMALE

# %%
#replace NaN values with new random values
warnings.simplefilter("ignore")
penguins1.loc[:,"Sex"]=Sex
       
penguins1
# Out:
#     studyName  Sample Number                              Species  Region  \
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 8     PAL0708              9  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 9     PAL0708             10  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 10    PAL0708             11  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 11    PAL0708             12  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 47    PAL0708             48  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 246   PAL0708             27    Gentoo penguin (Pygoscelis papua)  Anvers
# 286   PAL0809             67    Gentoo penguin (Pygoscelis papua)  Anvers
# 324   PAL0910            105    Gentoo penguin (Pygoscelis papua)  Anvers
# 339   PAL0910            120    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# ...

# %%
#replace the rows to the original dataframe
penguins.loc[penguins1.index, :] = penguins1[:]

# %%
penguins['Sex'].isnull().value_counts()
# Out:
# False    344
# Name: Sex, dtype: int64

# %%
penguins
# Out:
#     studyName  Sample Number                              Species  Region  \
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2     PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4     PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 339   PAL0910            120    Gentoo penguin (Pygoscelis papua)  Anvers
# 340   PAL0910            121    Gentoo penguin (Pygoscelis papua)  Anvers
# 341   PAL0910            122    Gentoo penguin (Pygoscelis papua)  Anvers
# 342   PAL0910            123    Gentoo penguin (Pygoscelis papua)  Anvers
# 343   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         Island               Stage Individual ID Clutch Completion  Date Egg  \
# ...
